# %%
list1=[1,2,3,4,5,7,8]
list2=["a","b","c","d","e"]

print ("Original key list is : " + str(list1)) 
print ("Original value list is : " + str(list2)) 

res1 = {list1[i]: list2[i] for i in range(len(list2))} 
  
print ("Resultant dictionary is : " +  str(res1))
# Out:
# Original key list is : [1, 2, 3, 4, 5, 7, 8]
# Original value list is : ['a', 'b', 'c', 'd', 'e']
# Resultant dictionary is : {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}
